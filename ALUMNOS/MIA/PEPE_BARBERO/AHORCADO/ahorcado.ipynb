# %%
with open('palabras.txt', 'r') as fichero:
    contenido = fichero.read()
    print(contenido)
# Out:
# MURCIELAGO
# VIAJE
# EVADIR
# ZAPATO
# CIELO
# RECREO
# PIZARRA
# MATEMATICAS
# PROGRAMACION
# ORDENADOR

# %%
with open ('palabras.txt', 'r') as fichero:
    for linea in fichero:
        print(linea.strip())
# Out:
# MURCIELAGO
# VIAJE
# EVADIR
# ZAPATO
# CIELO
# RECREO
# PIZARRA
# MATEMATICAS
# PROGRAMACION
# ORDENADOR

# %%
diccionario = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'Ñ', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']

intentos = 0
aciertos = 0 

with open ('palabras.txt', 'r') as fichero:
    for palabra in fichero:
        for letra in diccionario:
            intentos = intentos + 1
            if letra in palabra:
                print(letra.strip() + ' en ' + palabra.strip())
                aciertos = aciertos + 1
                if aciertos == len(palabra):
                    break
                



print (intentos)
print (aciertos)
# Out:
# A en MURCIELAGO
# C en MURCIELAGO
# E en MURCIELAGO
# G en MURCIELAGO
# I en MURCIELAGO
# L en MURCIELAGO
# M en MURCIELAGO
# O en MURCIELAGO
# R en MURCIELAGO
# U en MURCIELAGO
# A en VIAJE
# E en VIAJE
# I en VIAJE
# J en VIAJE
# V en VIAJE
# A en EVADIR
# D en EVADIR
# E en EVADIR
# I en EVADIR
# R en EVADIR
# V en EVADIR
# A en ZAPATO
# O en ZAPATO
# P en ZAPATO
# T en ZAPATO
# Z en ZAPATO
# C en CIELO
# E en CIELO
# I en CIELO
# L en CIELO
# O en CIELO
# C en RECREO
# E en RECREO
# O en RECREO
# R en RECREO
# A en PIZARRA
# I en PIZARRA
# P en PIZARRA
# R en PIZARRA
# Z en PIZARRA
# A en MATEMATICAS
# C en MATEMATICAS
# E en MATEMATICAS
# I en MATEMATICAS
# M en MATEMATICAS
# S en MATEMATICAS
# T en MATEMATICAS
# A en PROGRAMACION
# C en PROGRAMACION
# G en PROGRAMACION
# I en PROGRAMACION
# M en PROGRAMACION
# N en PROGRAMACION
# O en PROGRAMACION
# P en PROGRAMACION
# R en PROGRAMACION
# A en ORDENADOR
# D en ORDENADOR
# E en ORDENADOR
# N en ORDENADOR
# O en ORDENADOR
# R en ORDENADOR
# 270
# 62

# %%
diccionario = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'Ñ', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']

intentos = 0
aciertos = 0 

with open ('palabras.txt', 'r') as fichero:
    for palabra in fichero:
        for letra in diccionario:
            intentos = intentos + 1
            if letra in palabra:
                print(letra.strip() + ' en ' + palabra.strip())
                aciertos = aciertos + palabra.count(letra)
                if aciertos == len(palabra.strip()):
                    print ('Acerté la palabra')
                    aciertos = 0
                    break
                



print (intentos)
print (aciertos)
# Out:
# A en MURCIELAGO
# C en MURCIELAGO
# E en MURCIELAGO
# G en MURCIELAGO
# I en MURCIELAGO
# L en MURCIELAGO
# M en MURCIELAGO
# O en MURCIELAGO
# R en MURCIELAGO
# U en MURCIELAGO
# Acerté la palabra
# A en VIAJE
# E en VIAJE
# I en VIAJE
# J en VIAJE
# V en VIAJE
# Acerté la palabra
# A en EVADIR
# D en EVADIR
# E en EVADIR
# I en EVADIR
# R en EVADIR
# V en EVADIR
# Acerté la palabra
# A en ZAPATO
# O en ZAPATO
# P en ZAPATO
# T en ZAPATO
# Z en ZAPATO
# Acerté la palabra
# C en CIELO
# E en CIELO
# I en CIELO
# L en CIELO
# O en CIELO
# Acerté la palabra
# C en RECREO
# E en RECREO
# O en RECREO
# R en RECREO
# Acerté la palabra
# A en PIZARRA
# I en PIZARRA
# P en PIZARRA
# R en PIZARRA
# Z en PIZARRA
# Acerté la palabra
# A en MATEMATICAS
# C en MATEMATICAS
# E en MATEMATICAS
# I en MATEMATICAS
# M en MATEMATICAS
# S en MATEMATICAS
# T en MATEMATICAS
# Acerté la palabra
# A en PROGRAMACION
# C en PROGRAMACION
# G en PROGRAMACION
# I en PROGRAMACION
# M en PROGRAMACION
# N en PROGRAMACION
# O en PROGRAMACION
# P en PROGRAMACION
# R en PROGRAMACION
# Acerté la palabra
# A en ORDENADOR
# D en ORDENADOR
# E en ORDENADOR
# N en ORDENADOR
# O en ORDENADOR
# R en ORDENADOR
# Acerté la palabra
# 216
# 0

# %%
diccionario = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'Ñ', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
palabra = fichero.read().splitlines()

intentos = 0
aciertos = 0 

for palabra in fichero:
    for letra in diccionario:
        intentos = intentos + 1
        if letra in palabra:
            print(letra.strip() + ' en ' + palabra.strip())
            aciertos = aciertos + palabra.count(letra)
            if aciertos == len(palabra):
                print('Acerté la palabra')
                aciertos = aciertos + 0
                break
                



print (intentos)
print (aciertos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 diccionario = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'Ñ', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
# ----> 2 palabra = fichero.read().splitlines()
#       4 intentos = 0
#       5 aciertos = 0
#
# ValueError: I/O operation on closed file.
