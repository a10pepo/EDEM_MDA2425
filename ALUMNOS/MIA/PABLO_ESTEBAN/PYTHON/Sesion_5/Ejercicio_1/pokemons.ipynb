# %% [markdown]
# Lee el archivo CSV con Pandas de 'pokemon_data.csv' alojado en la carpeta de datos de este repositorio y realizar las siguientes operaciones

# %%
import pandas as pd
df = pd.read_csv('../../../../../../PROFESORES/PYTHON/Datos/pokemon_data.csv')

# %% [markdown]
# IMPRIMIR TODOS LOS VALORES

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# IMPRIMIR LOS PRIMEROS 5

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# IMPRIMIR LOS ÚLTIMOS 5

# %%
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# OBTENER NOMBRES DE LAS COLUMNAS

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# OBTENER TODOS LOS NOMBRES

# %%
df["Name"]
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# OBTENER TODOS LOS NOMBRES Y VELOCIDADES

# %%
df[["Name", "Speed"]]
# Out:
#                       Name  Speed
# 0                Bulbasaur     45
# 1                  Ivysaur     60
# 2                 Venusaur     80
# 3    VenusaurMega Venusaur     80
# 4               Charmander     65
# ..                     ...    ...
# 795                Diancie     50
# 796    DiancieMega Diancie    110
# 797    HoopaHoopa Confined     70
# 798     HoopaHoopa Unbound     80
# 799              Volcanion     70
#
# [800 rows x 2 columns]

# %% [markdown]
# LOS PRIMEROS 5 NOMBRES USANDO [::]

# %%
df['Name'].head()[::1]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %% [markdown]
# OBTENER TODAS LAS FILAS

# %%
df[:]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# OBTENER UN RANGO DE FILAS

# %%
df[20:40]
# Out:
#      #                 Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 20  16               Pidgey    Normal  Flying  40      45       40       35
# 21  17            Pidgeotto    Normal  Flying  63      60       55       50
# 22  18              Pidgeot    Normal  Flying  83      80       75       70
# 23  18  PidgeotMega Pidgeot    Normal  Flying  83      80       80      135
# 24  19              Rattata    Normal     NaN  30      56       35       25
# 25  20             Raticate    Normal     NaN  55      81       60       50
# 26  21              Spearow    Normal  Flying  40      60       30       31
# 27  22               Fearow    Normal  Flying  65      90       65       61
# 28  23                Ekans    Poison     NaN  35      60       44       40
# 29  24                Arbok    Poison     NaN  60      85       69       65
# 30  25              Pikachu  Electric     NaN  35      55       40       50
# ...

# %% [markdown]
# OBTENER EL NOMBRE DE LA FILA 10

# %%
df["Name"][10]
# Out:
# 'Wartortle'

# %% [markdown]
# ITERAR POR TODOS Y MOSTRAR EL ÍNDICE Y NOMBRE DE CADA FILA

# %%
for index, row in df.iterrows():
    print(f"Índice: {index}, Nombre: {row['Name']}")
# Out:
# Índice: 0, Nombre: Bulbasaur
# Índice: 1, Nombre: Ivysaur
# Índice: 2, Nombre: Venusaur
# Índice: 3, Nombre: VenusaurMega Venusaur
# Índice: 4, Nombre: Charmander
# Índice: 5, Nombre: Charmeleon
# Índice: 6, Nombre: Charizard
# Índice: 7, Nombre: CharizardMega Charizard X
# Índice: 8, Nombre: CharizardMega Charizard Y
# Índice: 9, Nombre: Squirtle
# Índice: 10, Nombre: Wartortle
# Índice: 11, Nombre: Blastoise
# Índice: 12, Nombre: BlastoiseMega Blastoise
# Índice: 13, Nombre: Caterpie
# Índice: 14, Nombre: Metapod
# Índice: 15, Nombre: Butterfree
# Índice: 16, Nombre: Weedle
# Índice: 17, Nombre: Kakuna
# Índice: 18, Nombre: Beedrill
# Índice: 19, Nombre: BeedrillMega Beedrill
# Índice: 20, Nombre: Pidgey
# Índice: 21, Nombre: Pidgeotto
# Índice: 22, Nombre: Pidgeot
# Índice: 23, Nombre: PidgeotMega Pidgeot
# Índice: 24, Nombre: Rattata
# Índice: 25, Nombre: Raticate
# Índice: 26, Nombre: Spearow
# Índice: 27, Nombre: Fearow
# Índice: 28, Nombre: Ekans
# Índice: 29, Nombre: Arbok
# ...

# %% [markdown]
# POKEMONS DE TIPO 1 == WATER

# %%
df[df['Type 1'] == 'Water']
# Out:
#        #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 9      7                 Squirtle  Water    NaN  44      48       65       50
# 10     8                Wartortle  Water    NaN  59      63       80       65
# 11     9                Blastoise  Water    NaN  79      83      100       85
# 12     9  BlastoiseMega Blastoise  Water    NaN  79     103      120      135
# 59    54                  Psyduck  Water    NaN  50      52       48       65
# ..   ...                      ...    ...    ...  ..     ...      ...      ...
# 724  656                  Froakie  Water    NaN  41      56       40       62
# 725  657                Frogadier  Water    NaN  54      63       52       83
# 726  658                 Greninja  Water   Dark  72      95       67      103
# 762  692                Clauncher  Water    NaN  50      53       62       58
# 763  693                Clawitzer  Water    NaN  71      73       88      120
#
# ...

# %% [markdown]
# ESTADÍSTICAS (usando Describe del DafaFrame)

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# ORDENACIÓN POR NOMBRE ASCENDENTE

# %%
df.sort_values('Name', ascending=True)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# CREAR UNA COLUMNA EXTRA CALCULADA
# - La columna debe ser la suma de HP + ATAQUE + DEFENSA + VELOCIDAD
# - La columna debe llamarse TOTAL

# %%
df['TOTAL'] = df['HP'] + df['Attack'] + df['Defense'] + df['Speed']
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  TOTAL
# 0       65     45           1      False    188
# 1       80     60           1      False    245
# 2      100     80           1      False    325
# 3      120     80           1      False    383
# 4       50     65           1      False    199

# %% [markdown]
# ELIMINAR LA COLUMNA TOTAL

# %%
df.drop('TOTAL', axis=1, inplace=True)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# FILTRAR POKEMONS DE TIPOS "GRASS" Y "POISON"

# %%
df[
    ((df['Type 1'] == 'Grass') | (df['Type 2'] == 'Grass')) &
    ((df['Type 1'] == 'Poison') | (df['Type 2'] == 'Poison'))
]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %% [markdown]
# FILTRAR POKEMONS DE TIPO "FIRE" Ó "POISON

# %%
df[
    (df['Type 1'] == 'Fire') | (df['Type 2'] == 'Fire') |
    (df['Type 1'] == 'Poison') | (df['Type 2'] == 'Poison')
]
# Out:
#        #                   Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur   Grass  Poison  45      49       49       65
# 1      2                Ivysaur   Grass  Poison  60      62       63       80
# 2      3               Venusaur   Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur   Grass  Poison  80     100      123      122
# 4      4             Charmander    Fire     NaN  39      52       43       60
# ..   ...                    ...     ...     ...  ..     ...      ...      ...
# 735  667                 Litleo    Fire  Normal  62      50       58       73
# 736  668                 Pyroar    Fire  Normal  86      68       72      109
# 760  690                 Skrelp  Poison   Water  50      60       60       60
# 761  691               Dragalge  Poison  Dragon  65      75       90       97
# 799  721              Volcanion    Fire   Water  80     110      120      130
#
# ...

# %% [markdown]
# FILTRAR POKEMONS DE TIPO "GRASS" Y "POISON" Y UN HP >= 70

# %%
df[
    ((df['Type 1'] == 'Grass') | (df['Type 2'] == 'Grass')) &
    ((df['Type 1'] == 'Poison') | (df['Type 2'] == 'Poison')) &
    (df['HP'] >= 70)
]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# 2        100     80           1      False
# 3        120     80           1      False
# 50        90     50           1      False
# 77        70     70           1      False
# 652       80     30           5      False

# %% [markdown]
# FILTRAR POKEMONS CON NOMBRE "MEGA"

# %%
df[df['Name'].str.contains("Mega", case=False, na=False)]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %% [markdown]
# FILTRAR POKEMONS SIN NOMBRE "MEGA"

# %%
df[~df['Name'].str.contains("Mega", case=False, na=False)]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %% [markdown]
# FILTRAR POKEMONS CUYOS NOMBRES COMIENCEN CON "PI"

# %%
df[df["Name"].str.startswith("Pi", na=False)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %% [markdown]
# RENOMBRADO DE COLUMNA "FIRE" a "FLAME"

# %%
df.rename(columns={'Fire': 'Flame'}, inplace=True)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# RENOMBRAR DE NUEVO A "FIRE" LA COLUMNA "FLAME" RECIÉN CAMBIADA

# %%
df.rename(columns={'Flame': 'Fire'}, inplace=True)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# CAMBIAR A TODOS LOS POKEMON LEGENDARIOS A TIPO "FIRE"

# %%
df.loc[df['Legendary'] == True, 'Type 1'] = 'Fire'
df[df['Legendary'] == True].head()
# Out:
#        #                 Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 156  144             Articuno   Fire    Flying   90      85      100       95
# 157  145               Zapdos   Fire    Flying   90      90       85      125
# 158  146              Moltres   Fire    Flying   90     100       90      125
# 162  150               Mewtwo   Fire       NaN  106     110       90      154
# 163  150  MewtwoMega Mewtwo X   Fire  Fighting  106     190      100      154
#
#      Sp. Def  Speed  Generation  Legendary
# 156      125     85           1       True
# 157       90    100           1       True
# 158       85     90           1       True
# 162       90    130           1       True
# 163      100    130           1       True

# %% [markdown]
# (Agrupación - groupBy) ESTADÍSTICAS DE MEDIA POR TIPO DE POKEMON y ORDENADOS POR DEFENSA

# %%
df.groupby('Type 1').mean(numeric_only=True).sort_values(by='Defense', ascending=False)
# Out:
#                    #         HP      Attack     Defense     Sp. Atk  \
# Type 1
# Steel     437.913043  60.434783   92.086957  126.652174   61.217391
# Rock      370.650000  65.125000   89.925000   97.125000   60.125000
# Fire      408.419643  81.973214  102.205357   84.919643  107.000000
# Ground    333.750000  70.821429   88.000000   79.821429   47.750000
# Ghost     486.466667  58.733333   71.366667   79.266667   77.300000
# Dragon    447.350000  72.650000  103.400000   78.150000   72.900000
# Water     300.490741  71.120370   72.777778   71.990741   72.305556
# Bug       334.492754  56.884058   70.971014   70.724638   53.869565
# Grass     336.074627  65.940299   72.119403   70.283582   76.343284
# Poison    251.785714  67.250000   74.678571   68.821429   60.428571
# Ice       438.318182  70.818182   73.227273   68.818182   75.727273
# Dark      451.517241  64.655172   86.862069   68.689655   70.620690
# Fighting  363.851852  69.851852   96.777778   65.925926   53.111111
# ...

# %% [markdown]
# (Agrupación - groupBy) ESTADÍSTICAS DE MEDIA POR TIPO DE POKEMON y ORDENADOS POR ATAQUE

# %%
df.groupby('Type 1').mean(numeric_only=True).sort_values(by='Attack', ascending=False)
# Out:
#                    #         HP      Attack     Defense     Sp. Atk  \
# Type 1
# Dragon    447.350000  72.650000  103.400000   78.150000   72.900000
# Fire      408.419643  81.973214  102.205357   84.919643  107.000000
# Fighting  363.851852  69.851852   96.777778   65.925926   53.111111
# Steel     437.913043  60.434783   92.086957  126.652174   61.217391
# Rock      370.650000  65.125000   89.925000   97.125000   60.125000
# Ground    333.750000  70.821429   88.000000   79.821429   47.750000
# Dark      451.517241  64.655172   86.862069   68.689655   70.620690
# Poison    251.785714  67.250000   74.678571   68.821429   60.428571
# Ice       438.318182  70.818182   73.227273   68.818182   75.727273
# Water     300.490741  71.120370   72.777778   71.990741   72.305556
# Grass     336.074627  65.940299   72.119403   70.283582   76.343284
# Normal    315.625000  76.489583   72.083333   58.697917   54.895833
# Ghost     486.466667  58.733333   71.366667   79.266667   77.300000
# ...

# %% [markdown]
# (Agrupación - groupBy) ESTADÍSTICAS DE MEDIA POR TIPO DE POKEMON y ORDENADOS POR HP

# %%
df.groupby('Type 1').mean(numeric_only=True).sort_values(by='HP', ascending=False)
# Out:
#                    #         HP      Attack     Defense     Sp. Atk  \
# Type 1
# Fire      408.419643  81.973214  102.205357   84.919643  107.000000
# Normal    315.625000  76.489583   72.083333   58.697917   54.895833
# Dragon    447.350000  72.650000  103.400000   78.150000   72.900000
# Water     300.490741  71.120370   72.777778   71.990741   72.305556
# Fairy     432.875000  70.875000   57.187500   63.875000   75.250000
# Ground    333.750000  70.821429   88.000000   79.821429   47.750000
# Ice       438.318182  70.818182   73.227273   68.818182   75.727273
# Fighting  363.851852  69.851852   96.777778   65.925926   53.111111
# Psychic   374.093023  67.720930   54.953488   61.000000   88.302326
# Poison    251.785714  67.250000   74.678571   68.821429   60.428571
# Grass     336.074627  65.940299   72.119403   70.283582   76.343284
# Rock      370.650000  65.125000   89.925000   97.125000   60.125000
# Dark      451.517241  64.655172   86.862069   68.689655   70.620690
# ...

# %% [markdown]
# (Agrupación - groupBy) ESTADÍSTICAS DE SUMA POR TIPO DE POKEMON

# %%
df.groupby('Type 1').sum(numeric_only=True)
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      13094  1875    2519     1992     2048     1967   2137         115
# Dragon     8947  1453    2068     1563     1458     1548   1447          75
# Electric  14322  2293    2645     2617     3451     2893   3291         131
# Fairy      6926  1134     915     1022     1204     1342    727          64
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Fire      45743  9181   11447     9511    11984    10131   9956         397
# Flying     1429   125     100      115      142      120    178          12
# Ghost     14594  1762    2141     2378     2319     2227   1879         126
# Grass     22517  4418    4832     4709     5115     4626   4000         222
# Ground     9345  1983    2464     2235     1337     1668   1673          85
# ...

# %% [markdown]
# (Agrupación - groupBy) ESTADÍSTICAS DE NÚMERO DE POKEMONS POR TIPO 1 DE POKEMON

# %%
df.groupby('Type 1').size()
# Out:
# Type 1
# Bug          69
# Dark         29
# Dragon       20
# Electric     40
# Fairy        16
# Fighting     27
# Fire        112
# Flying        2
# Ghost        30
# Grass        67
# Ground       28
# Ice          22
# Normal       96
# Poison       28
# Psychic      43
# Rock         40
# Steel        23
# Water       108
# dtype: int64

# %% [markdown]
# (Agrupación - groupBy) ESTADÍSTICAS DE NÚMERO DE POKEMONS POR TIPO 1 y 2 DE POKEMON

# %%
df.groupby(['Type 1', 'Type 2']).size()
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Length: 130, dtype: int64

# %% [markdown]
# Nota: SI TENEMOS ARCHIVOS ENORMES (1TB) PODEMOS LEERLOS POR PARTES Cada fila podría estar acumulando cerca de 20 bytes, por lo que podríamos estar trabajando con cantidades enormes

# %% [markdown]
# LEE EL ARCHIVO CVS SEPARÁNDOLO POR CHUNKS Y CON UN TAMAÑO DE (chunksize=5)

# %%
csv_chunks = pd.read_csv('../../../../../../PROFESORES/PYTHON/Datos/pokemon_data.csv', chunksize=5)

# %% [markdown]
# ITERA POR LOS CHUNKS Y MUÉSTRALOS POR CONSOLA

# %%
for i, chunk in enumerate(csv_chunks):
    print(f"Chunk {i + 1}:")
    print(chunk)
    print("\n")
# Out:
# Chunk 1:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#
#
# Chunk 2:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# ...
